# %% [markdown]
# # Natural Language Processing
# Detection of online sexism using NLTK library

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv("/content/edos-labelled-aggregated.csv",encoding = "ISO-8859-1")

# %% [markdown]
# ## Cleaning the texts

# %%
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
corpus = []
for i in range(0,20000):
  review = re.sub('[^a-zA-Z]', ' ', dataset['text'][i])
  review = review.lower()
  review = review.split()
  ps = PorterStemmer()
  all_stopwords = stopwords.words('english')
  all_stopwords.remove('not')
  review = [ps.stem(word) for word in review if not word in set(all_stopwords)]
  review = ' '.join(review)
  corpus.append(review)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
print(corpus)
# Out:
# ['crush retard feminist shit rot brain graduat colleg', 'u fuck wu', 'kill fast mayb natur way purg gene pool', 'rip david cassidi cousin actress shirley jone david cassidi stepmoth url', 'found twin look like fuck tranni lmfao', 'make person said enm relationship type that anoth way say women sleep lot random men without commit say slut said commonli hear refer', 'mean obviou sarah sex chang oper look face not dead giveaway', 'hahahahaha jame wood sh tposter heaven theresa hyena know woman ever met one burn stake', 'hey check freemonikaschaef help held crime think week contact allow outsid kill commi fer mommi', 'ok dude dislik comment afford women closer age guess', 'love katiehopkin give shit love stir black pot known evilislam banislam neversharia url', 'noth els kate steinl death honest testament race remain separ ration sens drug addl lazi dysgen brown individu ever share live space beauti white woman like kate', 'even racist peopl not live district repres million mansion affluent white neighborhood', 'women truli destroy nation hope enough men wake time around let women fight die conflict women caus', 'societi problem caus women choic muslim countri famili decid femoid', 'femal sentenc discount appal way articl read look though even face charg like welfar check let way', 'hillari busi look churchi tweet unicef go late got gal pal kati perri come one got one word say sum us haiti', 'make woman feel bad misogyni misogyni evil therefor make woman feel bad evil accord women', 'read feminazi articl men regularli abus femal janitor creat mess bathroom reveng know debunk complet unless women lesbian abus femal janitor way even', 'paid act derang peopl show movi hous diner ect know go must someon insid like woman babi call ex epa sec pruitt set', 'oh come not like femal mari sue exampl motherfuckin kaldor draigo tatsuya aizen batman etc still rustl jimmi', 'bull know shop keeper mani girl look given weekend shopkeep label forehead lol', 'crazi eye get hand bank account lol', 'good morn gabber coffe hot wife good mood sun rain trump still presid ask', 'devot husband ten year would leav instantli much smile', 'mother need day hassl go daili men noth relax get home', 'miss liber wrinkli ass bye bitch', 'seahawk player caught video taunt femal offic arrest scare got lot f king money broke wow url', 'project women must stolen line men forum women gener littl creativ', 'ask direct easier question famili lifestyl etc comment thing environ go philosoph abstract nervou like fail', 'touch ball check mean fell kinda like labia world chang', 'know get girl danc not want share playlist url', 'url hu tegh sohvad pagh maqam oh wighaj liber todsah vaj fuck aaaargh stand anymor liber idiot fuck discoveri startrek klingon warrior racist trump support', 'merylstreep use posit platform bulli trump support hypocrit hack', 'everi day traitor detest woman harm great britain damag parti complet failur pm one possibl imagin deep state keep power url', 'publicli flog men beat wive certain state pretti sure histori dv full lie half truth way feminist narr tend', 'man make tabl', 'women problem wage slave not perform enough replac', 'peopl need wake whole idea sharia concur jihad fear dislik muslim like ideolog', 'lili white tricki thing fond queer music queen favourit musician kill pedophil new music ever listen hail superwoman kate ryan', 'feel bad man part global depopul agenda url men subtli discourag marri women kid tend marri mgtow natur consequ realiz', 'thief opportunist vs idiot romant', 'disagre learn lot grandmoth', 'dude highli doubt better look small acn ridden phaggot still made girl what excus', 'saniti last michigan appeal court offici rule biolog men belong men not women locker room url', 'not im say stop incel ideolog high likelihood po base incel think women definit not po comment post show poster po', 'mr e edit new edit putin step way america step kill murder mother fucker assad fucker need die', 'not state bank screwool leftist mind  ...

# %% [markdown]
# ## Creating the Bag of Words model

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 1500)
X = cv.fit_transform(corpus).toarray()
y = dataset.iloc[:, 2].values

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %% [markdown]
# ## Training the Naive Bayes model on the Training set

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.svm import SVC
classifier = SVC();
classifier.fit(X_train, y_train)

# %% [markdown]
# ## Predicting the Test set results

# %%
y_pred = classifier.predict(X_test)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [['not sexist' 'not sexist']
#  ['not sexist' 'not sexist']
#  ['not sexist' 'not sexist']
#  ...
#  ['sexist' 'sexist']
#  ['not sexist' 'not sexist']
#  ['not sexist' 'not sexist']]

# %% [markdown]
# ## Making the Confusion Matrix

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#   not sexist       0.86      0.95      0.90      3010
#       sexist       0.76      0.51      0.61       990
#
#     accuracy                           0.84      4000
#    macro avg       0.81      0.73      0.76      4000
# weighted avg       0.83      0.84      0.83      4000

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[2850  160]
#  [ 482  508]]
# 0.8395
